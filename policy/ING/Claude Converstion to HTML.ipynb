# %% [markdown]
# # Convert ING pdf to HTML
# The ING policy is a complext set of tables sued to stucture the
# informatoin. This extensive use of tables did not convert well
# using standard tools such as mathpix or marker so we we use Claude sonnet
# to convert the

# %%
import os
from io import BytesIO
from pypdf import PdfReader, PdfWriter
import base64
from anthropic import Anthropic
from loguru import logger
from IPython.display import HTML
from dotenv import load_dotenv
from bs4 import BeautifulSoup

load_dotenv()
# Out:
# True

# %%
def pdf_to_html(pdf_base64_string: str) -> str:
        
    prompt = """Convert the PDF to a valid HTML including the <html>, <head> and <body> tags. Do not summarize or change the text, 
                just convert the PDF to HTML keeping the formatting as close as 
                possible to the original PDF. Remove page headers, footers, and page numbers.
                ensure there is a """
    messages = [
        {
            "role": 'user',
            "content": [
                {"type": "document", "source": {"type": "base64", "media_type": "application/pdf", "data": pdf_base64_string}},
                {"type": "text", "text": prompt}
            ]
        }
    ]

    # While PDF support is in beta, you must pass in the correct beta header
    client = Anthropic(default_headers={"anthropic-beta": "pdfs-2024-09-25"})
    
    # For now, only claude-3-5-sonnet-20241022 supports PDFs
    result = client.messages.create(
            model="claude-3-5-sonnet-20241022",
            max_tokens=8192,
            messages=messages
        )

    cost_cents = (result.usage.input_tokens * 3/1_000_000 + result.usage.output_tokens * 15/1_000_000) *100
    logger.info(f"cost ¢{cost_cents:.2f}, input_tokens={result.usage.input_tokens}, output_tokens={result.usage.output_tokens}")

    return result.content[0].text


def convert_page(page:str, n:int, cache_dir:str) -> str:
    
    file_name = f"{cache_dir}/page_{n}.html"
    if os.path.exists(file_name):
        logger.info(f"Using cached result in {file_name}")
        with open(file_name, "r") as f:
            return f.read()
        
    logger.info(f"Converting page {n}")
    # Create a new PDF writer with a single page
    writer = PdfWriter()
    writer.add_page(page)

    # Write to a BytesIO object
    pdf_bytes = BytesIO()
    writer.write(pdf_bytes)

    # PDF encoding as base64
    base64_string = base64.standard_b64encode(pdf_bytes.getvalue()).decode("utf-8")
    result = pdf_to_html(base64_string)
    
    # Cache the result to an HTML file
    with open(file_name, "w") as f:
        logger.info(f"Writing {file_name}")
        f.write(result)

    return result


# Read the PDF and write page 6 to memory
def convert_pdf(pdf_path:str, skip_pages: list = []) -> str:
    reader = PdfReader(pdf_path)
    doc_soup = BeautifulSoup("<html><head></head><body></body></html>", 'html.parser')
    
    base_name, _ = os.path.splitext(os.path.basename(pdf_path))
    directory = os.path.dirname(pdf_path)
    html_path = f"{directory}/{base_name}.html"
    cache_dir = f"{directory}/.html_cache"
    if not os.path.exists(cache_dir):
        os.makedirs(cache_dir)

    for i, page in enumerate(reader.pages):
        html = convert_page(page, i, cache_dir)
        if i in skip_pages:
            logger.info(f"Skipping page {i}")
        else:
            if page_soup := BeautifulSoup(html, 'html.parser').body:
                doc_soup.body.extend(page_soup.contents)
            else:
                logger.warning(f"Page {i} has no body")
    
    with open(html_path, "w") as f:
        f.write(str(doc_soup))
    
    return str(doc_soup)

# %%
policy_file = "./Manual/ING_residential_mortgage_underwriting_guidelines_broker_version.pdf" 
html = convert_pdf(policy_file, skip_pages=[1,2])
# HTML(html)
# Out:
# 2024-12-22 05:58:33.504 | INFO     | __main__:convert_page:37 - Using cached result in ./Manual/.html_cache/page_0.html
# 2024-12-22 05:58:33.512 | INFO     | __main__:convert_page:37 - Using cached result in ./Manual/.html_cache/page_1.html
# 2024-12-22 05:58:33.514 | INFO     | __main__:convert_pdf:77 - Skipping page 1
# 2024-12-22 05:58:33.516 | INFO     | __main__:convert_page:37 - Using cached result in ./Manual/.html_cache/page_2.html
# 2024-12-22 05:58:33.521 | INFO     | __main__:convert_pdf:77 - Skipping page 2
# 2024-12-22 05:58:33.522 | INFO     | __main__:convert_page:37 - Using cached result in ./Manual/.html_cache/page_3.html
# 2024-12-22 05:58:33.526 | INFO     | __main__:convert_page:37 - Using cached result in ./Manual/.html_cache/page_4.html
# 2024-12-22 05:58:33.533 | INFO     | __main__:convert_page:37 - Using cached result in ./Manual/.html_cache/page_5.html
# 2024-12-22 05:58:33.539 | INFO     | __main__:convert_page:37 - Using cached result in ./Manual/.html_cache/page_6.html
# 2024-12-22 05:58:33.544 | INFO     | __main__:convert_page:37 - Using cached result in ./Manual/.html_cache/page_7.html
# 2024-12-22 05:58:33.548 | INFO     | __main__:convert_page:37 - Using cached result in ./Manual/.html_cache/page_8.html
# 2024-12-22 05:58:33.554 | INFO     | __main__:convert_page:37 - Using cached result in ./Manual/.html_cache/page_9.html
# 2024-12-22 05:58:33.560 | INFO     | __main__:convert_page:37 - Using cached result in ./Manual/.html_cache/page_10.html
# 2024-12-22 05:58:33.565 | INFO     | __main__:convert_page:37 - Using cached result in ./Manual/.html_cache/page_11.html
# 2024-12-22 05:58:33.569 | INFO     | __main__:convert_page:37 - Using cached result in ./Manual/.html_cache/page_12.html
# 2024-12-22 05:58:33.576 | INFO     | __main__:convert_page:37 - Using cached result in ./Manual/.html_cache/page_13.html
# 2024-12-22 05:58:33.583 | INFO     | __main__:convert_page:37 - Using cached result in ./Manual/.html_cache/page_14.html
# 2024-12-22 05:58:33.589 | INFO     | __main__:convert_page:37 - Using cached result in ./Manual/.html_cache/page_15.html
# 2024-12-22 05:58:33.602 | INFO     | __main__:convert_page:37 - Using cached result in ./Manual/.html_cache/page_16.html
# 2024-12-22 05:58:33.605 | INFO     | __main__:convert_page:37 - Using cached result in ./Manual/.html_cache/page_17.html
# 2024-12-22 05:58:33.611 | INFO     | __main__:convert_page:37 - Using cached result in ./Manual/.html_cache/page_18.html
# 2024-12-22 05:58:33.616 | INFO     | __main__:convert_page:37 - Using cached result in ./Manual/.html_cache/page_19.html
# 2024-12-22 05:58:33.621 | INFO     | __main__:convert_page:37 - Using cached result in ./Manual/.html_cache/page_20.html
# 2024-12-22 05:58:33.626 | INFO     | __main__:convert_page:37 - Using cached result in ./Manual/.html_cache/page_21.html
# 2024-12-22 05:58:33.636 | INFO     | __main__:convert_page:37 - Using cached result in ./Manual/.html_cache/page_22.html
# 2024-12-22 05:58:33.646 | INFO     | __main__:convert_page:37 - Using cached result in ./Manual/.html_cache/page_23.html
# 2024-12-22 05:58:33.652 | INFO     | __main__:convert_page:37 - Using cached result in ./Manual/.html_cache/page_24.html
# 2024-12-22 05:58:33.664 | INFO     | __main__:convert_page:37 - Using cached result in ./Manual/.html_cache/page_25.html
# 2024-12-22 05:58:33.667 | INFO     | __main__:convert_page:37 - Using cached result in ./Manual/.html_cache/page_26.html
# 2024-12-22 05:58:33.674 | INFO     | __main__:convert_page:37 - Using cached result in ./Manual/.html_cache/page_27.html
# 2024-12-22 05:58:33.681 | INFO     | __main__:convert_page:37 - Using cached result in ./Manual/.html_cache/page_28.html
# 2024-12-22 05:58:33.686 | INFO     | __main__:convert_page:37 - Using cached result in ./Manual/.html_cache/page_29.html
# 2024-12-22 05:58:33.700 | INFO     | __main__:convert_page:37 - Using cached result in ./Manual/.html_cache/page_30.html
# 2024-12-22 05:58:33.710 | INFO     | __main__:convert_page:37 - Using cached result in ./Manual/.html_cache/page_31.html
# 2024-12-22 05:58:33.748 | INFO     | __main__:convert_page:37 - Using cached result in ./Manual/.html_cache/page_32.html
# 2024-12-22 05:58:33.758 | INFO     | __main__:convert_page:37 - Using cached result in ./Manual/.html_cache/page_33.html
# 2024-12-22 05:58:33.764 | INFO     | __main__:convert_page:37 - Using cached result in ./Manual/.html_cache/page_34.html
# 2024-12-22 05:58:33.769 | INFO     | __main__:convert_page:37 - Using cached result in ./Manual/.html_cache/page_35.html
# 2024-12-22 05:58:33.780 | INFO     | __main__:convert_page:37 - Using cached result in ./Manual/.html_cache/page_36.html
# 2024-12-22 05:58:33.805 | INFO     | __main__:convert_page:37 - Using cached result in ./Manual/.html_cache/page_37.html
# 2024-12-22 05:58:33.811 | INFO     | __main__:convert_page:37 - Using cached result in ./Manual/.html_cache/page_38.html
# 2024-12-22 05:58:33.816 | INFO     | __main__:convert_page:37 - Using cached result in ./Manual/.html_cache/page_39.html
# 2024-12-22 05:58:33.820 | INFO     | __main__:convert_page:37 - Using cached result in ./Manual/.html_cache/page_40.html
# 2024-12-22 05:58:33.831 | INFO     | __main__:convert_page:37 - Using cached result in ./Manual/.html_cache/page_41.html
# 2024-12-22 05:58:33.837 | INFO     | __main__:convert_page:37 - Using cached result in ./Manual/.html_cache/page_42.html
# 2024-12-22 05:58:33.846 | INFO     | __main__:convert_page:37 - Using cached result in ./Manual/.html_cache/page_43.html
# 2024-12-22 05:58:33.853 | INFO     | __main__:convert_page:37 - Using cached result in ./Manual/.html_cache/page_44.html
# 2024-12-22 05:58:33.861 | INFO     | __main__:convert_page:37 - Using cached result in ./Manual/.html_cache/page_45.html
# 2024-12-22 05:58:33.868 | INFO     | __main__:convert_page:37 - Using cached result in ./Manual/.html_cache/page_46.html
