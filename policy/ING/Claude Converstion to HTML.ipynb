# %% [markdown]
# # Convert ING pdf to HTML
# The ING policy is a complext set of tables sued to stucture the
# informatoin. This extensive use of tables did not convert well
# using standard tools such as mathpix or marker so we we use Claude sonnet
# to convert the

# %%
import os
from io import BytesIO
from pypdf import PdfReader, PdfWriter
import base64
from anthropic import Anthropic
from loguru import logger
from IPython.display import HTML
from dotenv import load_dotenv
from bs4 import BeautifulSoup

load_dotenv()
# Out:
# True

# %%
def pdf_to_html(pdf_base64_string: str) -> str:
        
    prompt = """Convert the PDF to a valid HTML including the <html>, <head> and <body> tags. Do not summarize or change the text, 
                just convert the PDF to HTML keeping the formatting as close as 
                possible to the original PDF. Remove page headers, footers, and page numbers.
                ensure there is a """
    messages = [
        {
            "role": 'user',
            "content": [
                {"type": "document", "source": {"type": "base64", "media_type": "application/pdf", "data": pdf_base64_string}},
                {"type": "text", "text": prompt}
            ]
        }
    ]

    # While PDF support is in beta, you must pass in the correct beta header
    client = Anthropic(default_headers={"anthropic-beta": "pdfs-2024-09-25"})
    
    # For now, only claude-3-5-sonnet-20241022 supports PDFs
    result = client.messages.create(
            model="claude-3-5-sonnet-20241022",
            max_tokens=8192,
            messages=messages
        )

    cost_cents = (result.usage.input_tokens * 3/1_000_000 + result.usage.output_tokens * 15/1_000_000) *100
    logger.info(f"cost ¢{cost_cents:.2f}, input_tokens={result.usage.input_tokens}, output_tokens={result.usage.output_tokens}")

    return result.content[0].text


def convert_page(page:str, n:int, cache_dir:str) -> str:
    
    file_name = f"{cache_dir}/page_{n}.html"
    if os.path.exists(file_name):
        logger.info(f"Using cached result in {file_name}")
        with open(file_name, "r") as f:
            return f.read()
        
    logger.info(f"Converting page {n}")
    # Create a new PDF writer with a single page
    writer = PdfWriter()
    writer.add_page(page)

    # Write to a BytesIO object
    pdf_bytes = BytesIO()
    writer.write(pdf_bytes)

    # PDF encoding as base64
    base64_string = base64.standard_b64encode(pdf_bytes.getvalue()).decode("utf-8")
    result = pdf_to_html(base64_string)
    
    # Cache the result to an HTML file
    with open(file_name, "w") as f:
        logger.info(f"Writing {file_name}")
        f.write(result)

    return result


# Read the PDF and write page 6 to memory
def convert_pdf(pdf_path:str, skip_pages: list = []) -> str:
    reader = PdfReader(pdf_path)
    doc_soup = BeautifulSoup("<html><head></head><body></body></html>", 'html.parser')
    
    base_name, _ = os.path.splitext(os.path.basename(pdf_path))
    directory = os.path.dirname(pdf_path)
    html_path = f"{directory}/{base_name}.html"
    cache_dir = f"{directory}/.html_cache"
    if not os.path.exists(cache_dir):
        os.makedirs(cache_dir)

    for i, page in enumerate(reader.pages):
        html = convert_page(page, i, cache_dir)
        if i in skip_pages:
            logger.info(f"Skipping page {i}")
        else:
            if page_soup := BeautifulSoup(html, 'html.parser').body:
                doc_soup.body.extend(page_soup.contents)
            else:
                logger.warning(f"Page {i} has no body")
    
    with open(html_path, "w") as f:
        f.write(str(doc_soup))
    
    return str(doc_soup)

# %%
policy_file = "./Manual/ING_residential_mortgage_underwriting_guidelines_broker_version.pdf" 
html = convert_pdf(policy_file, skip_pages=[1,2])
# HTML(html)
# Out:
# 2025-02-10 10:34:35.382 | INFO     | __main__:convert_page:41 - Converting page 0
# 2025-02-10 10:34:48.494 | INFO     | __main__:pdf_to_html:28 - cost ¢1.38, input_tokens=1798, output_tokens=563
# 2025-02-10 10:34:48.496 | INFO     | __main__:convert_page:56 - Writing ./Manual/.html_cache/page_0.html
# 2025-02-10 10:34:48.499 | INFO     | __main__:convert_page:41 - Converting page 1
# 2025-02-10 10:35:00.009 | INFO     | __main__:pdf_to_html:28 - cost ¢1.53, input_tokens=2074, output_tokens=608
# 2025-02-10 10:35:00.011 | INFO     | __main__:convert_page:56 - Writing ./Manual/.html_cache/page_1.html
# 2025-02-10 10:35:00.013 | INFO     | __main__:convert_pdf:77 - Skipping page 1
# 2025-02-10 10:35:00.013 | INFO     | __main__:convert_page:41 - Converting page 2
# 2025-02-10 10:35:17.971 | INFO     | __main__:pdf_to_html:28 - cost ¢1.82, input_tokens=2030, output_tokens=809
# 2025-02-10 10:35:17.973 | INFO     | __main__:convert_page:56 - Writing ./Manual/.html_cache/page_2.html
# 2025-02-10 10:35:17.975 | INFO     | __main__:convert_pdf:77 - Skipping page 2
# 2025-02-10 10:35:17.977 | INFO     | __main__:convert_page:41 - Converting page 3
# 2025-02-10 10:35:39.476 | INFO     | __main__:pdf_to_html:28 - cost ¢1.72, input_tokens=2002, output_tokens=747
# 2025-02-10 10:35:39.478 | INFO     | __main__:convert_page:56 - Writing ./Manual/.html_cache/page_3.html
# 2025-02-10 10:35:39.481 | INFO     | __main__:convert_page:41 - Converting page 4
# 2025-02-10 10:36:04.229 | INFO     | __main__:pdf_to_html:28 - cost ¢1.93, input_tokens=2058, output_tokens=872
# 2025-02-10 10:36:04.230 | INFO     | __main__:convert_page:56 - Writing ./Manual/.html_cache/page_4.html
# 2025-02-10 10:36:04.234 | INFO     | __main__:convert_page:41 - Converting page 5
# 2025-02-10 10:36:23.547 | INFO     | __main__:pdf_to_html:28 - cost ¢2.08, input_tokens=2032, output_tokens=981
# 2025-02-10 10:36:23.549 | INFO     | __main__:convert_page:56 - Writing ./Manual/.html_cache/page_5.html
# 2025-02-10 10:36:23.554 | INFO     | __main__:convert_page:41 - Converting page 6
# 2025-02-10 10:36:47.007 | INFO     | __main__:pdf_to_html:28 - cost ¢2.07, input_tokens=2227, output_tokens=936
# 2025-02-10 10:36:47.008 | INFO     | __main__:convert_page:56 - Writing ./Manual/.html_cache/page_6.html
# 2025-02-10 10:36:47.011 | INFO     | __main__:convert_page:41 - Converting page 7
# 2025-02-10 10:37:00.491 | INFO     | __main__:pdf_to_html:28 - cost ¢1.49, input_tokens=1951, output_tokens=602
# 2025-02-10 10:37:00.492 | INFO     | __main__:convert_page:56 - Writing ./Manual/.html_cache/page_7.html
# 2025-02-10 10:37:00.496 | INFO     | __main__:convert_page:41 - Converting page 8
# 2025-02-10 10:37:27.530 | INFO     | __main__:pdf_to_html:28 - cost ¢1.99, input_tokens=2174, output_tokens=892
# 2025-02-10 10:37:27.531 | INFO     | __main__:convert_page:56 - Writing ./Manual/.html_cache/page_8.html
# 2025-02-10 10:37:27.536 | INFO     | __main__:convert_page:41 - Converting page 9
# 2025-02-10 10:37:54.834 | INFO     | __main__:pdf_to_html:28 - cost ¢2.11, input_tokens=2272, output_tokens=955
# 2025-02-10 10:37:54.837 | INFO     | __main__:convert_page:56 - Writing ./Manual/.html_cache/page_9.html
# 2025-02-10 10:37:54.843 | INFO     | __main__:convert_page:41 - Converting page 10
# 2025-02-10 10:38:20.413 | INFO     | __main__:pdf_to_html:28 - cost ¢2.22, input_tokens=2246, output_tokens=1031
# 2025-02-10 10:38:20.415 | INFO     | __main__:convert_page:56 - Writing ./Manual/.html_cache/page_10.html
# 2025-02-10 10:38:20.419 | INFO     | __main__:convert_page:41 - Converting page 11
# 2025-02-10 10:38:44.270 | INFO     | __main__:pdf_to_html:28 - cost ¢1.83, input_tokens=2157, output_tokens=789
# 2025-02-10 10:38:44.272 | INFO     | __main__:convert_page:56 - Writing ./Manual/.html_cache/page_11.html
# 2025-02-10 10:38:44.278 | INFO     | __main__:convert_page:41 - Converting page 12
# 2025-02-10 10:39:12.465 | INFO     | __main__:pdf_to_html:28 - cost ¢2.18, input_tokens=2242, output_tokens=1007
# 2025-02-10 10:39:12.467 | INFO     | __main__:convert_page:56 - Writing ./Manual/.html_cache/page_12.html
# 2025-02-10 10:39:12.476 | INFO     | __main__:convert_page:41 - Converting page 13
# 2025-02-10 10:39:39.278 | INFO     | __main__:pdf_to_html:28 - cost ¢2.26, input_tokens=2290, output_tokens=1049
# 2025-02-10 10:39:39.284 | INFO     | __main__:convert_page:56 - Writing ./Manual/.html_cache/page_13.html
# 2025-02-10 10:39:39.288 | INFO     | __main__:convert_page:41 - Converting page 14
# 2025-02-10 10:39:54.839 | INFO     | __main__:pdf_to_html:28 - cost ¢1.53, input_tokens=1977, output_tokens=624
# 2025-02-10 10:39:54.840 | INFO     | __main__:convert_page:56 - Writing ./Manual/.html_cache/page_14.html
# 2025-02-10 10:39:54.843 | INFO     | __main__:convert_page:41 - Converting page 15
# 2025-02-10 10:40:17.842 | INFO     | __main__:pdf_to_html:28 - cost ¢2.03, input_tokens=2152, output_tokens=924
# 2025-02-10 10:40:17.843 | INFO     | __main__:convert_page:56 - Writing ./Manual/.html_cache/page_15.html
# 2025-02-10 10:40:17.850 | INFO     | __main__:convert_page:41 - Converting page 16
# 2025-02-10 10:40:35.845 | INFO     | __main__:pdf_to_html:28 - cost ¢1.58, input_tokens=2081, output_tokens=635
# 2025-02-10 10:40:35.846 | INFO     | __main__:convert_page:56 - Writing ./Manual/.html_cache/page_16.html
# 2025-02-10 10:40:35.848 | INFO     | __main__:convert_page:41 - Converting page 17
# 2025-02-10 10:40:51.628 | INFO     | __main__:pdf_to_html:28 - cost ¢1.62, input_tokens=1980, output_tokens=681
# 2025-02-10 10:40:51.630 | INFO     | __main__:convert_page:56 - Writing ./Manual/.html_cache/page_17.html
# 2025-02-10 10:40:51.632 | INFO     | __main__:convert_page:41 - Converting page 18
# 2025-02-10 10:41:11.801 | INFO     | __main__:pdf_to_html:28 - cost ¢1.92, input_tokens=2028, output_tokens=874
# 2025-02-10 10:41:11.803 | INFO     | __main__:convert_page:56 - Writing ./Manual/.html_cache/page_18.html
# 2025-02-10 10:41:11.810 | INFO     | __main__:convert_page:41 - Converting page 19
# 2025-02-10 10:41:32.634 | INFO     | __main__:pdf_to_html:28 - cost ¢1.74, input_tokens=2062, output_tokens=749
# 2025-02-10 10:41:32.636 | INFO     | __main__:convert_page:56 - Writing ./Manual/.html_cache/page_19.html
# 2025-02-10 10:41:32.639 | INFO     | __main__:convert_page:41 - Converting page 20
# 2025-02-10 10:41:43.355 | INFO     | __main__:pdf_to_html:28 - cost ¢1.23, input_tokens=1852, output_tokens=450
# 2025-02-10 10:41:43.356 | INFO     | __main__:convert_page:56 - Writing ./Manual/.html_cache/page_20.html
# 2025-02-10 10:41:43.360 | INFO     | __main__:convert_page:41 - Converting page 21
# 2025-02-10 10:42:01.606 | INFO     | __main__:pdf_to_html:28 - cost ¢1.99, input_tokens=2065, output_tokens=915
# 2025-02-10 10:42:01.608 | INFO     | __main__:convert_page:56 - Writing ./Manual/.html_cache/page_21.html
# 2025-02-10 10:42:01.614 | INFO     | __main__:convert_page:41 - Converting page 22
# 2025-02-10 10:42:25.269 | INFO     | __main__:pdf_to_html:28 - cost ¢2.14, input_tokens=2211, output_tokens=982
# 2025-02-10 10:42:25.270 | INFO     | __main__:convert_page:56 - Writing ./Manual/.html_cache/page_22.html
# 2025-02-10 10:42:25.273 | INFO     | __main__:convert_page:41 - Converting page 23
# 2025-02-10 10:42:51.586 | INFO     | __main__:pdf_to_html:28 - cost ¢2.29, input_tokens=2267, output_tokens=1070
# 2025-02-10 10:42:51.587 | INFO     | __main__:convert_page:56 - Writing ./Manual/.html_cache/page_23.html
# 2025-02-10 10:42:51.591 | INFO     | __main__:convert_page:41 - Converting page 24
# 2025-02-10 10:43:19.216 | INFO     | __main__:pdf_to_html:28 - cost ¢2.15, input_tokens=2177, output_tokens=995
# 2025-02-10 10:43:19.218 | INFO     | __main__:convert_page:56 - Writing ./Manual/.html_cache/page_24.html
# 2025-02-10 10:43:19.223 | INFO     | __main__:convert_page:41 - Converting page 25
# 2025-02-10 10:43:29.445 | INFO     | __main__:pdf_to_html:28 - cost ¢1.31, input_tokens=1817, output_tokens=513
# 2025-02-10 10:43:29.446 | INFO     | __main__:convert_page:56 - Writing ./Manual/.html_cache/page_25.html
# 2025-02-10 10:43:29.449 | INFO     | __main__:convert_page:41 - Converting page 26
# 2025-02-10 10:43:51.323 | INFO     | __main__:pdf_to_html:28 - cost ¢1.98, input_tokens=2145, output_tokens=893
# 2025-02-10 10:43:51.333 | INFO     | __main__:convert_page:56 - Writing ./Manual/.html_cache/page_26.html
# 2025-02-10 10:43:51.336 | INFO     | __main__:convert_page:41 - Converting page 27
# 2025-02-10 10:44:13.104 | INFO     | __main__:pdf_to_html:28 - cost ¢2.26, input_tokens=2217, output_tokens=1066
# 2025-02-10 10:44:13.107 | INFO     | __main__:convert_page:56 - Writing ./Manual/.html_cache/page_27.html
# 2025-02-10 10:44:13.114 | INFO     | __main__:convert_page:41 - Converting page 28
# 2025-02-10 10:44:24.294 | INFO     | __main__:pdf_to_html:28 - cost ¢1.27, input_tokens=1916, output_tokens=463
# 2025-02-10 10:44:24.295 | INFO     | __main__:convert_page:56 - Writing ./Manual/.html_cache/page_28.html
# 2025-02-10 10:44:24.297 | INFO     | __main__:convert_page:41 - Converting page 29
# 2025-02-10 10:44:43.624 | INFO     | __main__:pdf_to_html:28 - cost ¢1.90, input_tokens=2118, output_tokens=846
# 2025-02-10 10:44:43.626 | INFO     | __main__:convert_page:56 - Writing ./Manual/.html_cache/page_29.html
# 2025-02-10 10:44:43.631 | INFO     | __main__:convert_page:41 - Converting page 30
# 2025-02-10 10:44:56.704 | INFO     | __main__:pdf_to_html:28 - cost ¢1.47, input_tokens=1931, output_tokens=594
# 2025-02-10 10:44:56.705 | INFO     | __main__:convert_page:56 - Writing ./Manual/.html_cache/page_30.html
# 2025-02-10 10:44:56.708 | INFO     | __main__:convert_page:41 - Converting page 31
# 2025-02-10 10:45:25.934 | INFO     | __main__:pdf_to_html:28 - cost ¢2.49, input_tokens=2361, output_tokens=1188
# 2025-02-10 10:45:25.936 | INFO     | __main__:convert_page:56 - Writing ./Manual/.html_cache/page_31.html
# 2025-02-10 10:45:25.939 | INFO     | __main__:convert_page:41 - Converting page 32
# 2025-02-10 10:45:46.769 | INFO     | __main__:pdf_to_html:28 - cost ¢2.13, input_tokens=2303, output_tokens=957
# 2025-02-10 10:45:46.775 | INFO     | __main__:convert_page:56 - Writing ./Manual/.html_cache/page_32.html
# 2025-02-10 10:45:46.779 | INFO     | __main__:convert_page:41 - Converting page 33
# 2025-02-10 10:46:14.815 | INFO     | __main__:pdf_to_html:28 - cost ¢2.31, input_tokens=2264, output_tokens=1087
# 2025-02-10 10:46:14.816 | INFO     | __main__:convert_page:56 - Writing ./Manual/.html_cache/page_33.html
# 2025-02-10 10:46:14.819 | INFO     | __main__:convert_page:41 - Converting page 34
# 2025-02-10 10:46:23.057 | INFO     | __main__:pdf_to_html:28 - cost ¢0.92, input_tokens=1776, output_tokens=256
# 2025-02-10 10:46:23.065 | INFO     | __main__:convert_page:56 - Writing ./Manual/.html_cache/page_34.html
# 2025-02-10 10:46:23.067 | INFO     | __main__:convert_page:41 - Converting page 35
# 2025-02-10 10:46:42.665 | INFO     | __main__:pdf_to_html:28 - cost ¢2.12, input_tokens=2078, output_tokens=999
# 2025-02-10 10:46:42.667 | INFO     | __main__:convert_page:56 - Writing ./Manual/.html_cache/page_35.html
# 2025-02-10 10:46:42.672 | INFO     | __main__:convert_page:41 - Converting page 36
# 2025-02-10 10:47:06.186 | INFO     | __main__:pdf_to_html:28 - cost ¢2.16, input_tokens=2189, output_tokens=1005
# 2025-02-10 10:47:06.187 | INFO     | __main__:convert_page:56 - Writing ./Manual/.html_cache/page_36.html
# 2025-02-10 10:47:06.191 | INFO     | __main__:convert_page:41 - Converting page 37
# 2025-02-10 10:47:32.333 | INFO     | __main__:pdf_to_html:28 - cost ¢2.32, input_tokens=2386, output_tokens=1068
# 2025-02-10 10:47:32.335 | INFO     | __main__:convert_page:56 - Writing ./Manual/.html_cache/page_37.html
# 2025-02-10 10:47:32.341 | INFO     | __main__:convert_page:41 - Converting page 38
# 2025-02-10 10:47:52.472 | INFO     | __main__:pdf_to_html:28 - cost ¢2.30, input_tokens=2216, output_tokens=1090
# 2025-02-10 10:47:52.473 | INFO     | __main__:convert_page:56 - Writing ./Manual/.html_cache/page_38.html
# 2025-02-10 10:47:52.479 | INFO     | __main__:convert_page:41 - Converting page 39
# 2025-02-10 10:48:14.747 | INFO     | __main__:pdf_to_html:28 - cost ¢2.26, input_tokens=2218, output_tokens=1066
# 2025-02-10 10:48:14.750 | INFO     | __main__:convert_page:56 - Writing ./Manual/.html_cache/page_39.html
# 2025-02-10 10:48:14.760 | INFO     | __main__:convert_page:41 - Converting page 40
# 2025-02-10 10:48:30.627 | INFO     | __main__:pdf_to_html:28 - cost ¢1.84, input_tokens=2157, output_tokens=792
# 2025-02-10 10:48:30.628 | INFO     | __main__:convert_page:56 - Writing ./Manual/.html_cache/page_40.html
# 2025-02-10 10:48:30.632 | INFO     | __main__:convert_page:41 - Converting page 41
# 2025-02-10 10:48:53.992 | INFO     | __main__:pdf_to_html:28 - cost ¢2.28, input_tokens=2410, output_tokens=1035
# 2025-02-10 10:48:53.993 | INFO     | __main__:convert_page:56 - Writing ./Manual/.html_cache/page_41.html
# 2025-02-10 10:48:53.998 | INFO     | __main__:convert_page:41 - Converting page 42
# 2025-02-10 10:49:13.545 | INFO     | __main__:pdf_to_html:28 - cost ¢2.17, input_tokens=2287, output_tokens=990
# 2025-02-10 10:49:13.546 | INFO     | __main__:convert_page:56 - Writing ./Manual/.html_cache/page_42.html
# 2025-02-10 10:49:13.553 | INFO     | __main__:convert_page:41 - Converting page 43
# 2025-02-10 10:49:28.958 | INFO     | __main__:pdf_to_html:28 - cost ¢1.78, input_tokens=2090, output_tokens=767
# 2025-02-10 10:49:28.959 | INFO     | __main__:convert_page:56 - Writing ./Manual/.html_cache/page_43.html
# 2025-02-10 10:49:28.963 | INFO     | __main__:convert_page:41 - Converting page 44
# 2025-02-10 10:49:43.073 | INFO     | __main__:pdf_to_html:28 - cost ¢1.58, input_tokens=2060, output_tokens=639
# 2025-02-10 10:49:43.074 | INFO     | __main__:convert_page:56 - Writing ./Manual/.html_cache/page_44.html
